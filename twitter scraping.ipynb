# %%
import tweepy
from textblob import TextBlob

# Step 1 - Authenticate
consumer_key = 'WAHM8zyTCjHLyrFmdJ1BRBOFc'        #consumerkey string located in twitter apps
consumer_secret = 'Mqzu3XRWFYpTLxcLURidTXOQSTfJrADt5YyI9LTqYfF85GwBUx'    # consumer secret string located in twitter apps

access_token = '2388991603-1y8M2Aihmvsfvpou72EGuG1pb18uGoQhYbqXH0h'       # access token genrated in twitter apps
access_token_secret = 'IsldJ4CPVZINPxzzv5h23DuBGruxuayffVrbDmWtW655Y'    #access token secret genrated in twitter apps

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

#Step 3 - Retrieve Tweets

public_tweets = api.search('anabelle',count=1000)

#CHALLENGE - Instead of printing out each tweet, save each Tweet to a CSV file
#and label each one as either 'positive' or 'negative', depending on the sentiment 
#You can decide the sentiment polarity threshold yourself

count=0

for tweet in public_tweets:
    print(tweet.text)
    
    #Step 4 Perform Sentiment Analysis on Tweets
    analysis = TextBlob(tweet.text)
    print(analysis.sentiment)
    print("")
    count=count+1


print (count)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-1a8e9bb2aac2> in <module>()
# ----> 1 import tweepy
#       2 from textblob import TextBlob
#       3
#       4 # Step 1 - Authenticate
#       5 consumer_key = 'WAHM8zyTCjHLyrFmdJ1BRBOFc'        #consumerkey string located in twitter apps
#
# /Users/DBRSJ/Desktop/tweepy.py in <module>()
#       9 access_token_secret = 'IsldJ4CPVZINPxzzv5h23DuBGruxuayffVrbDmWtW655Y'    #access token secret genrated in twitter apps
#      10
# ---> 11 auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
#      12 auth.set_access_token(access_token, access_token_secret)
#      13
#
# AttributeError: module 'tweepy' has no attribute 'OAuthHandler'

# %%
from twitter import *
import pandas as pd
import bs4
# Step 1 - Authenticate
consumer_key = 'WAHM8zyTCjHLyrFmdJ1BRBOFc'        #consumerkey string located in twitter apps
consumer_secret = 'Mqzu3XRWFYpTLxcLURidTXOQSTfJrADt5YyI9LTqYfF85GwBUx'    # consumer secret string located in twitter apps

access_token = '2388991603-1y8M2Aihmvsfvpou72EGuG1pb18uGoQhYbqXH0h'       # access token genrated in twitter apps
access_token_secret = 'IsldJ4CPVZINPxzzv5h23DuBGruxuayffVrbDmWtW655Y'    #access token secret genrated in twitter apps


t = Twitter(
    auth= OAuth(access_token, access_token_secret, consumer_key, consumer_secret))


a=t.search.tweets(q="tarantula")

# %%
text_html = soup.findAll(, )
# Out:
# {'search_metadata': {'completed_in': 0.043,
#   'count': 15,
#   'max_id': 916555307785977856,
#   'max_id_str': '916555307785977856',
#   'next_results': '?max_id=916549221234376703&q=tarantula&include_entities=1',
#   'query': 'tarantula',
#   'refresh_url': '?since_id=916555307785977856&q=tarantula&include_entities=1',
#   'since_id': 0,
#   'since_id_str': '0'},
#  'statuses': [{'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sat Oct 07 06:46:28 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 916555307785977856,
#    'id_str': '916555307785977856',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': "Me: if you paid me a kazillion dollars then maybe I'd hold a tarantula \nKailha: I'd rather die.\n\n😂😂😂",
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Wed Oct 24 00:16:42 +0000 2012',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': '•W.O.U.• 🐾',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 4028,
#     'follow_request_sent': False,
#     'followers_count': 250,
#     'following': False,
#     'friends_count': 258,
#     'geo_enabled': False,
#     'has_extended_profile': True,
#     'id': 900848270,
#     'id_str': '900848270',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 0,
#     'location': '',
#     'name': 'Amber ✨',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/900848270/1448305890',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/915810492001673217/9J4NeCiU_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/915810492001673217/9J4NeCiU_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'AmberSimonson',
#     'statuses_count': 10887,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sat Oct 07 06:45:11 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 24135944,
#       'id_str': '24135944',
#       'indices': [0, 12],
#       'name': 'Bitch Murrow',
#       'screen_name': 'MitchBurrow'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 916554982660493312,
#    'id_str': '916554982660493312',
#    'in_reply_to_screen_name': 'MitchBurrow',
#    'in_reply_to_status_id': 915974272698408960,
#    'in_reply_to_status_id_str': '915974272698408960',
#    'in_reply_to_user_id': 24135944,
#    'in_reply_to_user_id_str': '24135944',
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Lite</a>',
#    'text': '@MitchBurrow Like that tarantula hawk wasp? Hit high notes easy',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sat Jun 13 22:29:12 +0000 2009',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': '@Hands4America #JoinHands4th of July Record video & write messages Journal4Troops #GodBlessAmerica',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': '911Unite.com',
#         'expanded_url': 'http://911Unite.com',
#         'indices': [0, 22],
#         'url': 'http://t.co/2NSUrewn45'}]}},
#     'favourites_count': 609,
#     'follow_request_sent': False,
#     'followers_count': 1423,
#     'following': False,
#     'friends_count': 2243,
#     'geo_enabled': True,
#     'has_extended_profile': True,
#     'id': 46977350,
#     'id_str': '46977350',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 20,
#     'location': 'Amarillo, TX',
#     'name': 'Lester L. Sullivan',
#     'notifications': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme10/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme10/bg.gif',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/46977350/1433360150',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/279141026/green_7194_Pa_til_Harvest_2008_073_normal.JPG',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/279141026/green_7194_Pa_til_Harvest_2008_073_normal.JPG',
#     'profile_link_color': '9266CC',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'Serjbart69',
#     'statuses_count': 11050,
#     'time_zone': 'Central Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'http://t.co/2NSUrewn45',
#     'utc_offset': -18000,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sat Oct 07 06:44:35 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'wired.com/2015/07/absurd…',
#       'expanded_url': 'https://www.wired.com/2015/07/absurd-creature-of-the-week-tarantula-hawk/?mbid=email_onsiteshare',
#       'indices': [108, 131],
#       'url': 'https://t.co/JfSSQzMaZ2'}],
#     'user_mentions': [{'id': 16892481,
#       'id_str': '16892481',
#       'indices': [3, 14],
#       'name': 'Nicholas Thompson',
#       'screen_name': 'nxthompson'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 916554833724887040,
#    'id_str': '916554833724887040',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 58,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Fri Oct 06 17:08:02 +0000 2017',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'display_url': 'wired.com/2015/07/absurd…',
#        'expanded_url': 'https://www.wired.com/2015/07/absurd-creature-of-the-week-tarantula-hawk/?mbid=email_onsiteshare',
#        'indices': [92, 115],
#        'url': 'https://t.co/JfSSQzMaZ2'}],
#      'user_mentions': []},
#     'favorite_count': 93,
#     'favorited': False,
#     'geo': None,
#     'id': 916349342134558720,
#     'id_str': '916349342134558720',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 58,
#     'retweeted': False,
#     'source': '<a href="http://bufferapp.com" rel="nofollow">Buffer</a>',
#     'text': 'Amazing: if a tarantula wasp stings you, the medical advice is just to lie down and scream. https://t.co/JfSSQzMaZ2',
#     'truncated': False,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Tue Oct 21 19:50:15 +0000 2008',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': '"My dad is head of Wired Magazine, which means he helps make Wired Magazine and smacks it on his head" -- my son.',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'wired.com',
#          'expanded_url': 'http://www.wired.com',
#          'indices': [0, 23],
#          'url': 'https://t.co/Dj9tIapXeo'}]}},
#      'favourites_count': 21737,
#      'follow_request_sent': False,
#      'followers_count': 82334,
#      'following': False,
#      'friends_count': 1463,
#      'geo_enabled': True,
#      'has_extended_profile': False,
#      'id': 16892481,
#      'id_str': '16892481',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 2467,
#      'location': 'New York',
#      'name': 'Nicholas Thompson',
#      'notifications': False,
#      'profile_background_color': 'C6E2EE',
#      'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/534454384982106112/LT_s7rnD.jpeg',
#      'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/534454384982106112/LT_s7rnD.jpeg',
#      'profile_background_tile': True,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/16892481/1486948297',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/831225388617650176/rIW1BkQ2_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/831225388617650176/rIW1BkQ2_normal.jpg',
#      'profile_link_color': '1F98C7',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'DAECF4',
#      'profile_text_color': '663B12',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'nxthompson',
#      'statuses_count': 20894,
#      'time_zone': 'Eastern Time (US & Canada)',
#      'translator_type': 'none',
#      'url': 'https://t.co/Dj9tIapXeo',
#      'utc_offset': -14400,
#      'verified': True}},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'text': 'RT @nxthompson: Amazing: if a tarantula wasp stings you, the medical advice is just to lie down and scream. https://t.co/JfSSQzMaZ2',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Thu Apr 09 19:08:29 +0000 2009',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Gamer, translator, vlogger, business owner, Bernie supporter, voted for Jill Stein. Tweet about Japanese gaming, anime, and general weeabooism. A.k.a Filler.',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'stores.ebay.com/playongo/',
#         'expanded_url': 'http://stores.ebay.com/playongo/',
#         'indices': [0, 23],
#         'url': 'https://t.co/Xcstfxdb2c'}]}},
#     'favourites_count': 62054,
#     'follow_request_sent': False,
#     'followers_count': 749,
#     'following': False,
#     'friends_count': 670,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 30044517,
#     'id_str': '30044517',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 63,
#     'location': 'Vermont, USA',
#     'name': 'Playongo',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/30044517/1437596491',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/696823779704573956/wNCrF78__normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/696823779704573956/wNCrF78__normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'playongo',
#     'statuses_count': 16175,
#     'time_zone': 'Quito',
#     'translator_type': 'none',
#     'url': 'https://t.co/Xcstfxdb2c',
#     'utc_offset': -18000,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sat Oct 07 06:43:19 +0000 2017',
#    'entities': {'hashtags': [],
#     'media': [{'display_url': 'pic.twitter.com/OPXnCueH3t',
#       'expanded_url': 'https://twitter.com/iamkeeferz/status/916554515125538818/photo/1',
#       'id': 916554507034812416,
#       'id_str': '916554507034812416',
#       'indices': [71, 94],
#       'media_url': 'http://pbs.twimg.com/media/DLhBd9EX4AAGQZD.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DLhBd9EX4AAGQZD.jpg',
#       'sizes': {'large': {'h': 526, 'resize': 'fit', 'w': 1024},
#        'medium': {'h': 526, 'resize': 'fit', 'w': 1024},
#        'small': {'h': 349, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/OPXnCueH3t'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'extended_entities': {'media': [{'display_url': 'pic.twitter.com/OPXnCueH3t',
#       'expanded_url': 'https://twitter.com/iamkeeferz/status/916554515125538818/photo/1',
#       'id': 916554507034812416,
#       'id_str': '916554507034812416',
#       'indices': [71, 94],
#       'media_url': 'http://pbs.twimg.com/media/DLhBd9EX4AAGQZD.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DLhBd9EX4AAGQZD.jpg',
#       'sizes': {'large': {'h': 526, 'resize': 'fit', 'w': 1024},
#        'medium': {'h': 526, 'resize': 'fit', 'w': 1024},
#        'small': {'h': 349, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/OPXnCueH3t'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 916554515125538818,
#    'id_str': '916554515125538818',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'text': "The tarantula nebula. \n\nSpace looks so crowded.  \n\nYet we're so alone. https://t.co/OPXnCueH3t",
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Sep 11 22:55:44 +0000 2012',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Livestreamer, entertainer, third-age getter',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'twitch.tv/iamkeeferz',
#         'expanded_url': 'http://www.twitch.tv/iamkeeferz',
#         'indices': [0, 23],
#         'url': 'https://t.co/89Zr507DvU'}]}},
#     'favourites_count': 8940,
#     'follow_request_sent': False,
#     'followers_count': 7085,
#     'following': False,
#     'friends_count': 1491,
#     'geo_enabled': False,
#     'has_extended_profile': True,
#     'id': 818357688,
#     'id_str': '818357688',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 13,
#     'location': 'www.twitch.tv/iamkeeferz ',
#     'name': 'iamkeeferz',
#     'notifications': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/818357688/1483589489',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/487337285583511553/_58E-deH_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/487337285583511553/_58E-deH_normal.png',
#     'profile_link_color': '4A913C',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'iamkeeferz',
#     'statuses_count': 18530,
#     'time_zone': 'Atlantic Time (Canada)',
#     'translator_type': 'none',
#     'url': 'https://t.co/89Zr507DvU',
#     'utc_offset': -10800,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sat Oct 07 06:43:09 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 916554471391588352,
#    'id_str': '916554471391588352',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://cheapbotsdonequick.com" rel="nofollow">Cheap Bots, Done Quick!</a>',
#    'text': 'Just call me Coco Tarantula-Tits.',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Apr 26 00:26:50 +0000 2016',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'wild bot in a wild world',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 9,
#     'follow_request_sent': False,
#     'followers_count': 10,
#     'following': False,
#     'friends_count': 3,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 724756587697573888,
#     'id_str': '724756587697573888',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 2,
#     'location': '',
#     'name': 'Coco Fantasy-Wrinkle',
#     'notifications': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/724770857491546112/olto_t32_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/724770857491546112/olto_t32_normal.jpg',
#     'profile_link_color': 'F58EA8',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'FantasyWrinkle',
#     'statuses_count': 25277,
#     'time_zone': 'Pacific Time (US & Canada)',
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': -25200,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sat Oct 07 06:38:45 +0000 2017',
#    'entities': {'hashtags': [{'indices': [16, 29], 'text': 'HubbleFriday'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 14091091,
#       'id_str': '14091091',
#       'indices': [3, 14],
#       'name': 'Hubble',
#       'screen_name': 'NASAHubble'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 916553362920816640,
#    'id_str': '916553362920816640',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 476,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Fri Oct 06 16:03:01 +0000 2017',
#     'entities': {'hashtags': [{'indices': [0, 13], 'text': 'HubbleFriday'}],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#        'expanded_url': 'https://twitter.com/i/web/status/916332980309778432',
#        'indices': [117, 140],
#        'url': 'https://t.co/l31G42iIDT'}],
#      'user_mentions': []},
#     'favorite_count': 1508,
#     'favorited': False,
#     'geo': None,
#     'id': 916332980309778432,
#     'id_str': '916332980309778432',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 476,
#     'retweeted': False,
#     'source': '<a href="https://www.sprinklr.com" rel="nofollow">Sprinklr</a>',
#     'text': '#HubbleFriday The Tarantula Nebula is 1 of the most intense regions of star formation in our galactic neighborhood:… https://t.co/l31G42iIDT',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Thu Mar 06 20:15:02 +0000 2008',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': 'The official Twitter account for the NASA Hubble Space Telescope.\n\n#SpotHubble',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'nasa.gov/mission_pages/…',
#          'expanded_url': 'http://www.nasa.gov/mission_pages/hubble/main/index.html',
#          'indices': [0, 22],
#          'url': 'http://t.co/3Jna7uw815'}]}},
#      'favourites_count': 490,
#      'follow_request_sent': False,
#      'followers_count': 4176423,
#      'following': False,
#      'friends_count': 141,
#      'geo_enabled': False,
#      'has_extended_profile': False,
#      'id': 14091091,
#      'id_str': '14091091',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 7290,
#      'location': 'Goddard Space Flight Center',
#      'name': 'Hubble',
#      'notifications': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/591287246193446913/sF1XSOIE.jpg',
#      'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/591287246193446913/sF1XSOIE.jpg',
#      'profile_background_tile': True,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/14091091/1504181613',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/3468011581/efb985f24af0a814a722457a768f3cc5_normal.jpeg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3468011581/efb985f24af0a814a722457a768f3cc5_normal.jpeg',
#      'profile_link_color': '0000FF',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': 'E0FF92',
#      'profile_text_color': '000000',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'NASAHubble',
#      'statuses_count': 4938,
#      'time_zone': 'Eastern Time (US & Canada)',
#      'translator_type': 'none',
#      'url': 'http://t.co/3Jna7uw815',
#      'utc_offset': -14400,
#      'verified': True}},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'text': 'RT @NASAHubble: #HubbleFriday The Tarantula Nebula is 1 of the most intense regions of star formation in our galactic neighborhood:\nhttps:/…',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Thu Apr 04 19:06:10 +0000 2013',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Inmunoparasitologo, politécnico.  Amante de los deportes, Aguila Blanca, Vikingo. Ah!! Roll tide!',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 53,
#     'follow_request_sent': False,
#     'followers_count': 60,
#     'following': False,
#     'friends_count': 148,
#     'geo_enabled': False,
#     'has_extended_profile': True,
#     'id': 1327599786,
#     'id_str': '1327599786',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'es',
#     'listed_count': 3,
#     'location': 'CDMX',
#     'name': 'Dr. Omar Hernández M',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/916171851436396549/TW2zrK6__normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/916171851436396549/TW2zrK6__normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'OmarHdezMontes',
#     'statuses_count': 5097,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sat Oct 07 06:38:16 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'favorite_count': 1,
#    'favorited': False,
#    'geo': None,
#    'id': 916553241646657536,
#    'id_str': '916553241646657536',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'und',
#    'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'text': '&lt;~&gt;',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sun Sep 10 11:55:48 +0000 2017',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': '어딘가 조금 이상한 철혈의 장갑 철댕이(tarantula) /기본적인 언어와 행동 구사',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 82,
#     'follow_request_sent': False,
#     'followers_count': 73,
#     'following': False,
#     'friends_count': 62,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 906848681797738497,
#     'id_str': '906848681797738497',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'ko',
#     'listed_count': 1,
#     'location': '어느 평야를 산책중',
#     'name': '장갑수색견',
#     'notifications': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/906848681797738497/1505045719',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/907723184052477952/uznbE3vE_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/907723184052477952/uznbE3vE_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'SF_tarantula',
#     'statuses_count': 1439,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sat Oct 07 06:37:31 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 805988789034192896,
#       'id_str': '805988789034192896',
#       'indices': [3, 15],
#       'name': 'Mely Bueno devera',
#       'screen_name': 'Buenomely27'},
#      {'id': 348874850,
#       'id_str': '348874850',
#       'indices': [17, 27],
#       'name': '🌺✨Vashna✨🌺',
#       'screen_name': 'grabesila'},
#      {'id': 3388030826,
#       'id_str': '3388030826',
#       'indices': [28, 38],
#       'name': '🌷JHING❤ 🌺💋',
#       'screen_name': 'jing9wabz'},
#      {'id': 3533201413,
#       'id_str': '3533201413',
#       'indices': [39, 46],
#       'name': '🔥🐓SentiEmoZen🌹🎶',
#       'screen_name': 'zenkmm'},
#      {'id': 3776248396,
#       'id_str': '3776248396',
#       'indices': [47, 58],
#       'name': 'SentiEmos💗Brussels',
#       'screen_name': 'fleurs7754'},
#      {'id': 3333364152,
#       'id_str': '3333364152',
#       'indices': [59, 67],
#       'name': 'Senti 🌈 Emos HGTX',
#       'screen_name': 'xinempl'},
#      {'id': 3688370840,
#       'id_str': '3688370840',
#       'indices': [68, 80],
#       'name': 'Mhel Lopez',
#       'screen_name': 'mhellopez19'},
#      {'id': 4880547524,
#       'id_str': '4880547524',
#       'indices': [81, 93],
#       'name': 'Senti💫EmosChie',
#       'screen_name': 'chie_chie26'},
#      {'id': 314155395,
#       'id_str': '314155395',
#       'indices': [94, 104],
#       'name': '👄SentiEmos🐼BeBe👄',
#       'screen_name': 'aizzgiant'},
#      {'id': 3670829834,
#       'id_str': '3670829834',
#       'indices': [105, 115],
#       'name': 'fejosede2',
#       'screen_name': 'fejosede2'},
#      {'id': 750270199966773250,
#       'id_str': '750270199966773250',
#       'indices': [116, 123],
#       'name': 'MZ',
#       'screen_name': 'emzsmf'},
#      {'id': 4442787675,
#       'id_str': '4442787675',
#       'indices': [124, 135],
#       'name': 'Ellina Gen',
#       'screen_name': 'ellina_gen'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 916553054450737153,
#    'id_str': '916553054450737153',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'eu',
#    'metadata': {'iso_language_code': 'eu', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 22,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Fri Oct 06 17:51:59 +0000 2017',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#        'expanded_url': 'https://twitter.com/i/web/status/916360399691300864',
#        'indices': [108, 131],
#        'url': 'https://t.co/1i2xzkoFLJ'}],
#      'user_mentions': [{'id': 348874850,
#        'id_str': '348874850',
#        'indices': [0, 10],
#        'name': '🌺✨Vashna✨🌺',
#        'screen_name': 'grabesila'},
#       {'id': 3388030826,
#        'id_str': '3388030826',
#        'indices': [11, 21],
#        'name': '🌷JHING❤ 🌺💋',
#        'screen_name': 'jing9wabz'},
#       {'id': 3533201413,
#        'id_str': '3533201413',
#        'indices': [22, 29],
#        'name': '🔥🐓SentiEmoZen🌹🎶',
#        'screen_name': 'zenkmm'},
#       {'id': 3776248396,
#        'id_str': '3776248396',
#        'indices': [30, 41],
#        'name': 'SentiEmos💗Brussels',
#        'screen_name': 'fleurs7754'},
#       {'id': 3333364152,
#        'id_str': '3333364152',
#        'indices': [42, 50],
#        'name': 'Senti 🌈 Emos HGTX',
#        'screen_name': 'xinempl'},
#       {'id': 3688370840,
#        'id_str': '3688370840',
#        'indices': [51, 63],
#        'name': 'Mhel Lopez',
#        'screen_name': 'mhellopez19'},
#       {'id': 4880547524,
#        'id_str': '4880547524',
#        'indices': [64, 76],
#        'name': 'Senti💫EmosChie',
#        'screen_name': 'chie_chie26'},
#       {'id': 314155395,
#        'id_str': '314155395',
#        'indices': [77, 87],
#        'name': '👄SentiEmos🐼BeBe👄',
#        'screen_name': 'aizzgiant'},
#       {'id': 3670829834,
#        'id_str': '3670829834',
#        'indices': [88, 98],
#        'name': 'fejosede2',
#        'screen_name': 'fejosede2'},
#       {'id': 750270199966773250,
#        'id_str': '750270199966773250',
#        'indices': [99, 106],
#        'name': 'MZ',
#        'screen_name': 'emzsmf'}]},
#     'favorite_count': 1,
#     'favorited': False,
#     'geo': None,
#     'id': 916360399691300864,
#     'id_str': '916360399691300864',
#     'in_reply_to_screen_name': 'Buenomely27',
#     'in_reply_to_status_id': 916359836756992000,
#     'in_reply_to_status_id_str': '916359836756992000',
#     'in_reply_to_user_id': 805988789034192896,
#     'in_reply_to_user_id_str': '805988789034192896',
#     'is_quote_status': False,
#     'lang': 'eu',
#     'metadata': {'iso_language_code': 'eu', 'result_type': 'recent'},
#     'place': None,
#     'retweet_count': 22,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'text': '@grabesila @jing9wabz @zenkmm @fleurs7754 @xinempl @mhellopez19 @chie_chie26 @aizzgiant @fejosede2 @emzsmf… https://t.co/1i2xzkoFLJ',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Tue Dec 06 04:14:36 +0000 2016',
#      'default_profile': True,
#      'default_profile_image': False,
#      'description': 'Born December 27\nSuper fan and love Maine and Alden❤❤❤💛💛💛\nHongkong',
#      'entities': {'description': {'urls': []}},
#      'favourites_count': 8231,
#      'follow_request_sent': False,
#      'followers_count': 839,
#      'following': False,
#      'friends_count': 437,
#      'geo_enabled': False,
#      'has_extended_profile': False,
#      'id': 805988789034192896,
#      'id_str': '805988789034192896',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 5,
#      'location': '',
#      'name': 'Mely Bueno devera',
#      'notifications': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/805988789034192896/1492430759',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/847360076926955523/_KWDZNdW_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/847360076926955523/_KWDZNdW_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'Buenomely27',
#      'statuses_count': 200334,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': None,
#      'utc_offset': None,
#      'verified': False}},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'text': 'RT @Buenomely27: @grabesila @jing9wabz @zenkmm @fleurs7754 @xinempl @mhellopez19 @chie_chie26 @aizzgiant @fejosede2 @emzsmf @ellina_gen @le…',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sat Jan 07 10:00:30 +0000 2017',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': '',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 5314,
#     'follow_request_sent': False,
#     'followers_count': 149,
#     'following': False,
#     'friends_count': 211,
#     'geo_enabled': False,
#     'has_extended_profile': True,
#     'id': 817672248039309313,
#     'id_str': '817672248039309313',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 0,
#     'location': '',
#     'name': 'ALDUB Maria😇',
#     'notifications': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/818838805293645824/j1P_kfoY_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/818838805293645824/j1P_kfoY_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'candykendi222',
#     'statuses_count': 65804,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sat Oct 07 06:27:21 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'wired.com/2015/07/absurd…',
#       'expanded_url': 'https://www.wired.com/2015/07/absurd-creature-of-the-week-tarantula-hawk/?mbid=email_onsiteshare',
#       'indices': [108, 131],
#       'url': 'https://t.co/JfSSQzMaZ2'}],
#     'user_mentions': [{'id': 16892481,
#       'id_str': '16892481',
#       'indices': [3, 14],
#       'name': 'Nicholas Thompson',
#       'screen_name': 'nxthompson'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 916550494222299136,
#    'id_str': '916550494222299136',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 58,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Fri Oct 06 17:08:02 +0000 2017',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'display_url': 'wired.com/2015/07/absurd…',
#        'expanded_url': 'https://www.wired.com/2015/07/absurd-creature-of-the-week-tarantula-hawk/?mbid=email_onsiteshare',
#        'indices': [92, 115],
#        'url': 'https://t.co/JfSSQzMaZ2'}],
#      'user_mentions': []},
#     'favorite_count': 93,
#     'favorited': False,
#     'geo': None,
#     'id': 916349342134558720,
#     'id_str': '916349342134558720',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 58,
#     'retweeted': False,
#     'source': '<a href="http://bufferapp.com" rel="nofollow">Buffer</a>',
#     'text': 'Amazing: if a tarantula wasp stings you, the medical advice is just to lie down and scream. https://t.co/JfSSQzMaZ2',
#     'truncated': False,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Tue Oct 21 19:50:15 +0000 2008',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': '"My dad is head of Wired Magazine, which means he helps make Wired Magazine and smacks it on his head" -- my son.',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'wired.com',
#          'expanded_url': 'http://www.wired.com',
#          'indices': [0, 23],
#          'url': 'https://t.co/Dj9tIapXeo'}]}},
#      'favourites_count': 21737,
#      'follow_request_sent': False,
#      'followers_count': 82334,
#      'following': False,
#      'friends_count': 1463,
#      'geo_enabled': True,
#      'has_extended_profile': False,
#      'id': 16892481,
#      'id_str': '16892481',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 2467,
#      'location': 'New York',
#      'name': 'Nicholas Thompson',
#      'notifications': False,
#      'profile_background_color': 'C6E2EE',
#      'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/534454384982106112/LT_s7rnD.jpeg',
#      'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/534454384982106112/LT_s7rnD.jpeg',
#      'profile_background_tile': True,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/16892481/1486948297',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/831225388617650176/rIW1BkQ2_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/831225388617650176/rIW1BkQ2_normal.jpg',
#      'profile_link_color': '1F98C7',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'DAECF4',
#      'profile_text_color': '663B12',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'nxthompson',
#      'statuses_count': 20894,
#      'time_zone': 'Eastern Time (US & Canada)',
#      'translator_type': 'none',
#      'url': 'https://t.co/Dj9tIapXeo',
#      'utc_offset': -14400,
#      'verified': True}},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'RT @nxthompson: Amazing: if a tarantula wasp stings you, the medical advice is just to lie down and scream. https://t.co/JfSSQzMaZ2',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sat Mar 28 00:51:01 +0000 2009',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'DẸ̢͎̜͚͇̄̐͆͌͊̚ͅS̵̪͖̲̻͛ͯͮ̈́͡ IGN',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'melvinalvarez.com',
#         'expanded_url': 'http://melvinalvarez.com',
#         'indices': [0, 23],
#         'url': 'https://t.co/VrIYNEN3tE'}]}},
#     'favourites_count': 6466,
#     'follow_request_sent': False,
#     'followers_count': 243,
#     'following': False,
#     'friends_count': 218,
#     'geo_enabled': True,
#     'has_extended_profile': True,
#     'id': 27142201,
#     'id_str': '27142201',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 18,
#     'location': 'San Francisco, CA',
#     'name': 'Melvin Alvarez',
#     'notifications': False,
#     'profile_background_color': '022330',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/27142201/1495158168',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/914968416988958720/FVBOG-sC_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/914968416988958720/FVBOG-sC_normal.jpg',
#     'profile_link_color': '000000',
#     'profile_sidebar_border_color': 'A8C7F7',
#     'profile_sidebar_fill_color': 'C0DFEC',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'melvinismad',
#     'statuses_count': 3921,
#     'time_zone': 'Hong Kong',
#     'translator_type': 'none',
#     'url': 'https://t.co/VrIYNEN3tE',
#     'utc_offset': 28800,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sat Oct 07 06:25:37 +0000 2017',
#    'entities': {'hashtags': [{'indices': [16, 29], 'text': 'HubbleFriday'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 14091091,
#       'id_str': '14091091',
#       'indices': [3, 14],
#       'name': 'Hubble',
#       'screen_name': 'NASAHubble'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 916550057519857664,
#    'id_str': '916550057519857664',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 476,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Fri Oct 06 16:03:01 +0000 2017',
#     'entities': {'hashtags': [{'indices': [0, 13], 'text': 'HubbleFriday'}],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#        'expanded_url': 'https://twitter.com/i/web/status/916332980309778432',
#        'indices': [117, 140],
#        'url': 'https://t.co/l31G42iIDT'}],
#      'user_mentions': []},
#     'favorite_count': 1508,
#     'favorited': False,
#     'geo': None,
#     'id': 916332980309778432,
#     'id_str': '916332980309778432',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 476,
#     'retweeted': False,
#     'source': '<a href="https://www.sprinklr.com" rel="nofollow">Sprinklr</a>',
#     'text': '#HubbleFriday The Tarantula Nebula is 1 of the most intense regions of star formation in our galactic neighborhood:… https://t.co/l31G42iIDT',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Thu Mar 06 20:15:02 +0000 2008',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': 'The official Twitter account for the NASA Hubble Space Telescope.\n\n#SpotHubble',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'nasa.gov/mission_pages/…',
#          'expanded_url': 'http://www.nasa.gov/mission_pages/hubble/main/index.html',
#          'indices': [0, 22],
#          'url': 'http://t.co/3Jna7uw815'}]}},
#      'favourites_count': 490,
#      'follow_request_sent': False,
#      'followers_count': 4176423,
#      'following': False,
#      'friends_count': 141,
#      'geo_enabled': False,
#      'has_extended_profile': False,
#      'id': 14091091,
#      'id_str': '14091091',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 7290,
#      'location': 'Goddard Space Flight Center',
#      'name': 'Hubble',
#      'notifications': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/591287246193446913/sF1XSOIE.jpg',
#      'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/591287246193446913/sF1XSOIE.jpg',
#      'profile_background_tile': True,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/14091091/1504181613',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/3468011581/efb985f24af0a814a722457a768f3cc5_normal.jpeg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3468011581/efb985f24af0a814a722457a768f3cc5_normal.jpeg',
#      'profile_link_color': '0000FF',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': 'E0FF92',
#      'profile_text_color': '000000',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'NASAHubble',
#      'statuses_count': 4938,
#      'time_zone': 'Eastern Time (US & Canada)',
#      'translator_type': 'none',
#      'url': 'http://t.co/3Jna7uw815',
#      'utc_offset': -14400,
#      'verified': True}},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'RT @NASAHubble: #HubbleFriday The Tarantula Nebula is 1 of the most intense regions of star formation in our galactic neighborhood:\nhttps:/…',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Fri Jun 24 15:46:16 +0000 2016',
#     'default_profile': True,
#     'default_profile_image': False,
# ...
#      {'id': 750270199966773250,
#       'id_str': '750270199966773250',
#       'indices': [116, 123],
#       'name': 'MZ',
#       'screen_name': 'emzsmf'},
#      {'id': 4442787675,
#       'id_str': '4442787675',
#       'indices': [124, 135],
#       'name': 'Ellina Gen',
#       'screen_name': 'ellina_gen'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 916549397898338304,
#    'id_str': '916549397898338304',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'eu',
#    'metadata': {'iso_language_code': 'eu', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 22,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Fri Oct 06 17:51:59 +0000 2017',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#        'expanded_url': 'https://twitter.com/i/web/status/916360399691300864',
#        'indices': [108, 131],
#        'url': 'https://t.co/1i2xzkoFLJ'}],
#      'user_mentions': [{'id': 348874850,
#        'id_str': '348874850',
#        'indices': [0, 10],
#        'name': '🌺✨Vashna✨🌺',
#        'screen_name': 'grabesila'},
#       {'id': 3388030826,
#        'id_str': '3388030826',
#        'indices': [11, 21],
#        'name': '🌷JHING❤ 🌺💋',
#        'screen_name': 'jing9wabz'},
#       {'id': 3533201413,
#        'id_str': '3533201413',
#        'indices': [22, 29],
#        'name': '🔥🐓SentiEmoZen🌹🎶',
#        'screen_name': 'zenkmm'},
#       {'id': 3776248396,
#        'id_str': '3776248396',
#        'indices': [30, 41],
#        'name': 'SentiEmos💗Brussels',
#        'screen_name': 'fleurs7754'},
#       {'id': 3333364152,
#        'id_str': '3333364152',
#        'indices': [42, 50],
#        'name': 'Senti 🌈 Emos HGTX',
#        'screen_name': 'xinempl'},
#       {'id': 3688370840,
#        'id_str': '3688370840',
#        'indices': [51, 63],
#        'name': 'Mhel Lopez',
#        'screen_name': 'mhellopez19'},
#       {'id': 4880547524,
#        'id_str': '4880547524',
#        'indices': [64, 76],
#        'name': 'Senti💫EmosChie',
#        'screen_name': 'chie_chie26'},
#       {'id': 314155395,
#        'id_str': '314155395',
#        'indices': [77, 87],
#        'name': '👄SentiEmos🐼BeBe👄',
#        'screen_name': 'aizzgiant'},
#       {'id': 3670829834,
#        'id_str': '3670829834',
#        'indices': [88, 98],
#        'name': 'fejosede2',
#        'screen_name': 'fejosede2'},
#       {'id': 750270199966773250,
#        'id_str': '750270199966773250',
#        'indices': [99, 106],
#        'name': 'MZ',
#        'screen_name': 'emzsmf'}]},
#     'favorite_count': 1,
#     'favorited': False,
#     'geo': None,
#     'id': 916360399691300864,
#     'id_str': '916360399691300864',
#     'in_reply_to_screen_name': 'Buenomely27',
#     'in_reply_to_status_id': 916359836756992000,
#     'in_reply_to_status_id_str': '916359836756992000',
#     'in_reply_to_user_id': 805988789034192896,
#     'in_reply_to_user_id_str': '805988789034192896',
#     'is_quote_status': False,
#     'lang': 'eu',
#     'metadata': {'iso_language_code': 'eu', 'result_type': 'recent'},
#     'place': None,
#     'retweet_count': 22,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'text': '@grabesila @jing9wabz @zenkmm @fleurs7754 @xinempl @mhellopez19 @chie_chie26 @aizzgiant @fejosede2 @emzsmf… https://t.co/1i2xzkoFLJ',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Tue Dec 06 04:14:36 +0000 2016',
#      'default_profile': True,
#      'default_profile_image': False,
#      'description': 'Born December 27\nSuper fan and love Maine and Alden❤❤❤💛💛💛\nHongkong',
#      'entities': {'description': {'urls': []}},
#      'favourites_count': 8231,
#      'follow_request_sent': False,
#      'followers_count': 839,
#      'following': False,
#      'friends_count': 437,
#      'geo_enabled': False,
#      'has_extended_profile': False,
#      'id': 805988789034192896,
#      'id_str': '805988789034192896',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 5,
#      'location': '',
#      'name': 'Mely Bueno devera',
#      'notifications': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/805988789034192896/1492430759',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/847360076926955523/_KWDZNdW_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/847360076926955523/_KWDZNdW_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'Buenomely27',
#      'statuses_count': 200334,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': None,
#      'utc_offset': None,
#      'verified': False}},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'text': 'RT @Buenomely27: @grabesila @jing9wabz @zenkmm @fleurs7754 @xinempl @mhellopez19 @chie_chie26 @aizzgiant @fejosede2 @emzsmf @ellina_gen @le…',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Thu May 25 09:24:19 +0000 2017',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Kapit lang ng kapit',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 327,
#     'follow_request_sent': False,
#     'followers_count': 44,
#     'following': False,
#     'friends_count': 64,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 867672669252014080,
#     'id_str': '867672669252014080',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 1,
#     'location': '',
#     'name': 'MAICHARD',
#     'notifications': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/867672669252014080/1495704748',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/867674725266411521/hblzEN_U_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/867674725266411521/hblzEN_U_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'YayadubAlden',
#     'statuses_count': 12916,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sat Oct 07 06:22:36 +0000 2017',
#    'entities': {'hashtags': [{'indices': [16, 29], 'text': 'HubbleFriday'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 14091091,
#       'id_str': '14091091',
#       'indices': [3, 14],
#       'name': 'Hubble',
#       'screen_name': 'NASAHubble'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 916549301802647553,
#    'id_str': '916549301802647553',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 476,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Fri Oct 06 16:03:01 +0000 2017',
#     'entities': {'hashtags': [{'indices': [0, 13], 'text': 'HubbleFriday'}],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#        'expanded_url': 'https://twitter.com/i/web/status/916332980309778432',
#        'indices': [117, 140],
#        'url': 'https://t.co/l31G42iIDT'}],
#      'user_mentions': []},
#     'favorite_count': 1508,
#     'favorited': False,
#     'geo': None,
#     'id': 916332980309778432,
#     'id_str': '916332980309778432',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 476,
#     'retweeted': False,
#     'source': '<a href="https://www.sprinklr.com" rel="nofollow">Sprinklr</a>',
#     'text': '#HubbleFriday The Tarantula Nebula is 1 of the most intense regions of star formation in our galactic neighborhood:… https://t.co/l31G42iIDT',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Thu Mar 06 20:15:02 +0000 2008',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': 'The official Twitter account for the NASA Hubble Space Telescope.\n\n#SpotHubble',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'nasa.gov/mission_pages/…',
#          'expanded_url': 'http://www.nasa.gov/mission_pages/hubble/main/index.html',
#          'indices': [0, 22],
#          'url': 'http://t.co/3Jna7uw815'}]}},
#      'favourites_count': 490,
#      'follow_request_sent': False,
#      'followers_count': 4176423,
#      'following': False,
#      'friends_count': 141,
#      'geo_enabled': False,
#      'has_extended_profile': False,
#      'id': 14091091,
#      'id_str': '14091091',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 7290,
#      'location': 'Goddard Space Flight Center',
#      'name': 'Hubble',
#      'notifications': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/591287246193446913/sF1XSOIE.jpg',
#      'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/591287246193446913/sF1XSOIE.jpg',
#      'profile_background_tile': True,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/14091091/1504181613',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/3468011581/efb985f24af0a814a722457a768f3cc5_normal.jpeg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3468011581/efb985f24af0a814a722457a768f3cc5_normal.jpeg',
#      'profile_link_color': '0000FF',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': 'E0FF92',
#      'profile_text_color': '000000',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'NASAHubble',
#      'statuses_count': 4938,
#      'time_zone': 'Eastern Time (US & Canada)',
#      'translator_type': 'none',
#      'url': 'http://t.co/3Jna7uw815',
#      'utc_offset': -14400,
#      'verified': True}},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'RT @NASAHubble: #HubbleFriday The Tarantula Nebula is 1 of the most intense regions of star formation in our galactic neighborhood:\nhttps:/…',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sun Jul 10 13:57:39 +0000 2011',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': '',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 61,
#     'follow_request_sent': False,
#     'followers_count': 3,
#     'following': False,
#     'friends_count': 33,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 332826280,
#     'id_str': '332826280',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'ko',
#     'listed_count': 0,
#     'location': '',
#     'name': 'cheyenne 744',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/332826280/1451799723',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/2309918272/image_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2309918272/image_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'cheyenne_744',
#     'statuses_count': 70,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sat Oct 07 06:22:17 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 916549221234376704,
#    'id_str': '916549221234376704',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'text': "WHATTER'YEW askin?\nIf I don't have the answer, it's probably on the web, like I'm a damn tarantula.",
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Fri Apr 17 16:26:33 +0000 2009',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Sneaker collector supreme. Steelers. Pirates. Penguins. Nerdy shit excites me. Stark in the streets, Dothraki in the sheets. Well bred & well read.',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 6428,
#     'follow_request_sent': False,
#     'followers_count': 839,
#     'following': False,
#     'friends_count': 578,
#     'geo_enabled': False,
#     'has_extended_profile': True,
#     'id': 32467287,
#     'id_str': '32467287',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 27,
#     'location': 'Steeler Nation',
#     'name': 'Eleven',
#     'notifications': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme10/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme10/bg.gif',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/32467287/1491449583',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/909759982761009153/D7_xUM4s_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/909759982761009153/D7_xUM4s_normal.jpg',
#     'profile_link_color': '9266CC',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'D0MXNXQUE',
#     'statuses_count': 195589,
#     'time_zone': 'Pacific Time (US & Canada)',
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': -25200,
#     'verified': False}}]}
